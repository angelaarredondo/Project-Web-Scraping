# %%
# !pip install simple_colors
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simple_colors
#   Downloading simple_colors-0.1.5-py3-none-any.whl (2.8 kB)
# Installing collected packages: simple-colors
# Successfully installed simple-colors-0.1.5

# %%
# !pip install yagmail
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yagmail
#   Downloading yagmail-0.15.293-py2.py3-none-any.whl (17 kB)
# Collecting premailer
#   Downloading premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# Collecting cssutils
#   Downloading cssutils-2.6.0-py3-none-any.whl (399 kB)
#      |████████████████████████████████| 399 kB 58.1 MB/s
# Requirement already satisfied: cachetools in /usr/local/lib/python3.7/dist-packages (from premailer->yagmail) (5.2.0)
# Collecting cssselect
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from premailer->yagmail) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from premailer->yagmail) (4.9.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from cssutils->premailer->yagmail) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->cssutils->premailer->yagmail) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->cssutils->premailer->yagmail) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->premailer->yagmail) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->premailer->yagmail) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->premailer->yagmail) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->premailer->yagmail) (1.24.3)
# Installing collected packages: cssutils, cssselect, premailer, yagmail
# Successfully installed cssselect-1.2.0 cssutils-2.6.0 premailer-3.10.0 yagmail-0.15.293

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import sys
from simple_colors import *
from IPython.display import clear_output
import random
import yagmail
import getpass

# %%
colors = [red,magenta,yellow,green,blue,cyan,red,magenta,yellow,green,blue,cyan,red,magenta,yellow,green,blue,cyan]

def print_slowly(text):
    count=0
    for c in text:
        print(colors[count](c,'italic')),
        sys.stdout.flush()
        count+=1
        time.sleep(0.25)

# %%
#Import laptops CSV

laptops = pd.read_csv('laptops.csv',header=0,index_col=0)
laptops
# Out:
#                                                  Name   Price          Brand  \
# 0   Lenovo IdeaPad 3 15ITL6, 15.6" Full HD, Intel®...  545.00         LENOVO
# 1   Acer A315-56-304W, 15.6" Full HD, Intel® Core™...  459.00           ACER
# 2   HP 15S-EQ1040NS, 15.6" HD, AMD 3020e, 4GB, 128...  369.00             HP
# 3   82KD00ENSP LENOVO, 15,6", Full-HD, AMD Ryzen 3...  397.28         LENOVO
# 4   Acer Swift 3 SF314-511-525P, 14" FHD, Intel® C...  780.00           ACER
# ..                                                ...     ...            ...
# 66  Microsoft Surface Pro 8-13" Touchscreen - Inte...  859.99      MICROSOFT
# 67  2022 Latest Lenovo ThinkPad E15 Gen 3 15.6" FH...  869.98  IST COMPUTERS
# 68   ASUS TUF Dash 15 (2021) Ultra Slim Gaming Laptop  884.00           ASUS
# 69  2022 Latest Lenovo ThinkPad E15 15.6" FHD (Int...  899.98  IST COMPUTERS
# 70             Dell G15 15.6" FHD 120Hz Gaming Laptop  989.00           DELL
#
#     Review counts  Review score Product status Company name  \
# 0               7           4.5      Brand New   Mediamarkt
# 1               0           0.0      Brand New   Mediamarkt
# 2               5           4.5      Brand New   Mediamarkt
# 3               0           0.0      Brand New   Mediamarkt
# 4               4           3.0      Brand New   Mediamarkt
# ..            ...           ...            ...          ...
# 66              4           4.4      Brand New       Amazon
# 67             22           4.5      Brand New       Amazon
# 68            231           4.5      Brand New       Amazon
# 69             19           4.4      Brand New       Amazon
# 70              3           4.4      Brand New       Amazon
#
#                                                  Link  RAM RAM Type  \
# 0   https://www.mediamarkt.es/es/product/_portatil...    8     RAM1
# 1   https://www.mediamarkt.es/es/product/_portatil...    8     RAM1
# 2   https://www.mediamarkt.es/es/product/_portatil...    4     RAM1
# 3   https://www.mediamarkt.es/es/product/_portatil...    8     RAM1
# 4   https://www.mediamarkt.es/es/product/_portatil...   16     RAM2
# ..                                                ...  ...      ...
# 66  https://www.amazon.com/Microsoft-Surface-Pro-8...    8     RAM1
# 67  https://www.amazon.com/ThinkPad-E15-Gen3-1920x...   16     RAM2
# 68  https://www.amazon.com/ASUS-GeForce-i7-11370H-...    8     RAM1
# 69  https://www.amazon.com/ThinkPad-E15-1920x1080-...   16     RAM2
# 70  https://www.amazon.com/Dell-GeForce-3200MHz-Ba...   32     RAM3
#
#     Ratio RAM/€
# 0      0.014679
# 1      0.017429
# 2      0.010840
# 3      0.020137
# 4      0.020513
# ..          ...
# 66     0.009302
# 67     0.018391
# 68     0.009050
# 69     0.017778
# 70     0.032356
#
# [1797 rows x 11 columns]

# %%
#Import screens CSV

screens = pd.read_csv('screens.csv',header=0,index_col=0)
screens
# Out:
#                                                   Name   Price    Brand  \
# 0    Monitor - Samsung LU28R550UQRXEN, 28" UHD 4K, ...  199.00  SAMSUNG
# 1    Monitor - Samsung LS27BM501EUXEN, 27" FHD, 4 m...  299.00  SAMSUNG
# 2    Monitor - LG 27UL500-W, 27" UHD 4K, 5ms, 60 Hz...  273.00       LG
# 3    Monitor - 34WQ60C LG, 34", QHD, 1 ms, Displayp...  347.42       LG
# 4    Monitor - P34hc G4 HP, 34", WQHD, 5 ms, DVI|Di...  475.78       HP
# ..                                                 ...     ...      ...
# 182  U2311HB 23" Widescreen LED Monitor Black(1920x...   69.31     DELL
# 183  Z24i 24" LED Backlit IPS 16:10 Monitor Black(1...  213.78       HP
# 184  E231 23" LED Backlit 16:9 Monitor Black(1920x1...  139.73       HP
# 185  P2412H 24" LED Monitor Black(1920x1080) - HA -...   92.36     DELL
# 186  U2412M 24" IPS Monitor Black(1920x1200) - HA -...  115.61     DELL
#
#      Review counts  Review score Product status     Company name  \
# 0                5           4.5      Brand New       Mediamarkt
# 1                0           0.0      Brand New       Mediamarkt
# 2               17           4.5      Brand New       Mediamarkt
# 3                0           0.0      Brand New       Mediamarkt
# 4                1           5.0      Brand New       Mediamarkt
# ..             ...           ...            ...              ...
# 182              0           0.0    Refurbished  Segunda Mano PC
# 183              0           0.0    Refurbished  Segunda Mano PC
# 184              0           0.0    Refurbished  Segunda Mano PC
# 185              0           0.0    Refurbished  Segunda Mano PC
# 186              0           0.0    Refurbished  Segunda Mano PC
#
#                                                   Link  Inches Inches Type  \
# 0    https://www.mediamarkt.es/es/product/_monitor-...    28.0       Inch2
# 1    https://www.mediamarkt.es/es/product/_monitor-...    27.0       Inch3
# 2    https://www.mediamarkt.es/es/product/_monitor-...    27.0       Inch3
# 3    https://www.mediamarkt.es/es/product/_monitor-...    34.0       Inch2
# 4    https://www.mediamarkt.es/es/product/_monitor-...    34.0       Inch2
# ..                                                 ...     ...         ...
# 182  https://www.segundamanopc.com/es/monitores/216...    23.0       Inch1
# 183  https://www.segundamanopc.com/es/monitores/216...    24.0       Inch1
# 184  https://www.segundamanopc.com/es/monitores/216...    23.0       Inch1
# 185  https://www.segundamanopc.com/es/monitores/216...    24.0       Inch1
# 186  https://www.segundamanopc.com/es/monitores/214...    24.0       Inch1
#
#      Ratio Inches/€
# 0          0.140704
# 1          0.090301
# 2          0.098901
# 3          0.097864
# 4          0.071462
# ..              ...
# 182        0.331842
# 183        0.112265
# 184        0.164603
# 185        0.259853
# 186        0.207594
#
# [545 rows x 11 columns]

# %%
#INTRODUCING THE PROGRAM TO THE USER

print(blue('# Ironhack Kit Starter Recommendation System #', 'bold'))
time.sleep(1.5)
print('\n')

print('Are you starting your '+(black('Ironhack adventure ','bold'))+'and still need a '+(black('new equipment','bold'))+ ' to work with?')
time.sleep(2.5)
print('\n')

print('🤩 Please, let us help you!')
time.sleep(1.5)
print('\n')

print_slowly('# LOADING #')
print('\n')
time.sleep(1)
clear_output(wait=True)

#ASKING FOR THE NAME

n = print('🤔 First we need to know your '+(black('name ','bold'))+': ')
print('\n')
time.sleep(0.5)
n = str(input('Name: '))
time.sleep(1.5)
print('\n')

print_slowly('# LOADING #')
print('\n')
time.sleep(1)
clear_output(wait=True)

#ASKING FOR THE EMAIL

e = print('Welcome '+(black(n,'italic'))+'! We need also your 📧 ' +(black('email','bold'))+' to send you our recommendations : ')
print('\n')
time.sleep(0.5)
e = str(input('Email: '))
print('\n')
i = False
while i == False:
  
  if not ("@") in e:
    print(e+ red(' does not like an email. Please, try again'))
    print('\n')
    time.sleep(0.5)
    e = str(input('Email: '))
    print('\n')
  else:
    i = True
    print_slowly('# LOADING #')

print('\n')
print(green('Thank you for sharing us your email!'))
time.sleep(1.5)
clear_output(wait=True)


#PICK A CHOICE BETWEEN ITEMS OR BRAND INFO
m = True

while m == True:

  print('We can give you a recommendation about which '+(black('kit set','bold'))+(black(' (laptop+screen) ','italic'))+ 'fits better for you, or general info about ' +(black('laptop/screen brands','bold')))

  time.sleep(1)
  print('\n')

  print('What '+(black('information ','bold'))+'are you interested in?')
  print('\n')
  time.sleep(0.5)
  print('❓ 1. Information about laptop/screen Brands')
  print('💻 2. Best Kit Starter for you')
  print('💨 3. EXIT')
  print('\n')
  choice1 = str(input('Write the number of your choice: '))
  time.sleep(0.5)

  i = False
  list=['1','2']
  list1=['1','2','3'] 

  while i == False:

    if choice1 not in list1:
      print('\n')
      print(red('Wrong. Please, try again'))
      print('\n')
      time.sleep(0.5)
      print('❓ 1. Information about laptop/screen Brands')
      print('💻 2. Best Starter Kit for you')
      print('\n')
      choice1 = str(input('Write the number of your choice: '))
      time.sleep(0.5)

    elif choice1 == '3':
      print('\n')
      print('Goodbye! See you soon')
      m = False
      break

    else:
      i = True
      print('\n')
      print_slowly('# LOADING #')

  time.sleep(1.5)
  print('\n')
  clear_output(wait=True)

  #FOLLOW UP WITH THE CHOSEN CHOICE

  #CHOICE = 1 - BRAND INFORMATION
  #1ST - LAPTOP OR SCREEN?

  if choice1 == '1':
    print('The '+(black('brand of which object ','bold'))+' are you interested in?')
    print('\n')
    time.sleep(0.5)
    print('💻 1. Laptop')
    print('📺 2. Screen')
    print('\n')
    choice2 = str(input('Write the number of your choice: '))
    time.sleep(0.5)

    i = False
    
    while i == False:

      if choice2 not in list:
        print('\n')
        print(red('Wrong. Please, try again'))
        print('\n')
        time.sleep(0.5)
        print('💻 1. Laptop')
        print('📺 2. Screen')
        print('\n')
        choice2 = str(input('Write the number of your choice: '))
        time.sleep(0.5)

      else:
        i = True
        print('\n')
        print_slowly('# LOADING #')

    time.sleep(1.5)
    print('\n')
    clear_output(wait=True)

  #2ND - BRAND NEW OR SECOND HAND

    print('Are you interested in '+(black('Brand New','bold'))+' or '+(black('Second-hand','bold'))+' items?')
    print('\n')
    time.sleep(0.5)
    print('👶 1. Brand New')
    print('👴 2. Second-hand')
    print('\n')
    choice3 = str(input('Write the number of your choice: '))
    time.sleep(0.5)

    i = False
    
    while i == False:

      if choice3 not in list:
        print('\n')
        print(red('Wrong. Please, try again'))
        print('\n')
        time.sleep(0.5)
        print('👶 1. Brand New')
        print('👴 2. Second-hand')
        print('\n')
        choice3 = str(input('Write the number of your choice: '))
        time.sleep(0.5)

      else:
        i = True
        print('\n')
        print_slowly('# LOADING #')

    time.sleep(1.5)
    print('\n')
    clear_output(wait=True)

    # BRAND NEW LAPTOP BRANDS
    if choice2 == '1' and choice3 =='1':
      print('These are the '+(black('average New Brand laptop prices','bold'))+' per '+(black('brand','bold'))+' and '+(black('GB.','bold')))
      print('\n')
      brand_laptop_info_new = (laptops[laptops['Product status'] == 'Brand New']).groupby(['Brand','RAM']).agg({'Price':'mean'}).sort_values(by = 'Price', ascending = False).reset_index()
      print(brand_laptop_info_new)
      print('\n')
      print('\n')

    # SECOND HAND LAPTOP BRANDS
    if choice2 == '1' and choice3 =='2':
      print('These are the '+(black('average Second hand laptop prices','bold'))+' per '+(black('brand','bold'))+' and '+(black('GB.','bold')))
      print('\n')
      brand_laptop_info_refur = (laptops[laptops['Product status'] == 'Refurbished']).groupby(['Brand','RAM']).agg({'Price':'mean'}).sort_values(by = 'Price', ascending = False).reset_index()
      print(brand_laptop_info_refur)
      print('\n')
      print('\n')

    # BRAND NEW SCREENS BRANDS
    if choice2 == '2' and choice3 =='1':
      print('These are the '+(black('average Second hand screen prices','bold'))+' per '+(black('brand','bold'))+' and '+(black('Inches Type.','bold')))
      print('\n')
      print((black('Type Inches Segmentation','bold')))
      print('\n')
      print((black('Type Inch1: ','bold'))+'below 27"')
      print('\n')
      print((black('Type Inch2: ','bold'))+'above 27 and below 40"')
      print('\n')
      print((black('Type Inch3: ','bold'))+'above 40"')
      print('\n')
      brand_screen_info_new = (screens[screens['Product status'] == 'Brand New']).groupby(['Brand','Inches Type']).agg({'Price':'mean'}).sort_values(by = 'Price', ascending = False).reset_index()
      print(brand_screen_info_new)
      print('\n')
      print('\n')
   
    # SECOND HAND SCREENS BRANDS
    if choice2 == '2' and choice3 =='2':
      print('These are the '+(black('average Second hand screen prices','bold'))+' per '+(black('brand','bold'))+' and '+(black('Inches.','bold')))
      print('\n')
      print((black('Type Inches Segmentation','bold')))
      print('\n')
      print((black('Type Inch1: ','bold'))+'below 27"')
      print('\n')
      print((black('Type Inch2: ','bold'))+'above 27 and below 40"')
      print('\n')
      print((black('Type Inch3: ','bold'))+'above 40"')
      print('\n')
      brand_screen_info_refur = (screens[screens['Product status'] == 'Refurbished']).groupby(['Brand','Inches Type']).agg({'Price':'mean'}).sort_values(by = 'Price', ascending = False).reset_index()
      print(brand_screen_info_refur)
      print('\n')
      print('\n')


    #CONTINUE?


    print('Do you want to keep going? Y/N')
    print('\n')
    continue1 = str(input('Write your choice: '))
    print('\n')


    if continue1.lower() == 'y':
      m = True
      clear_output(wait=True)
    elif continue1.lower() == 'n':
      m = False
      break
    else:
      m = False
      break



    #BEST STARTER KIT INFO



  elif choice1 == '2':
    #Run code about Best Starter Kit info
    print('GO ON STARTER KIT INFO')
    print((black('Which object ','bold'))+' are you interested in?')
    print('\n')
    time.sleep(0.5)
    print('💻 1. Laptop')
    print('📺 2. Screen')
    print('\n')
    choice4 = str(input('Write the number of your choice: '))
    time.sleep(0.5)

    i = False
    
    while i == False:

      if choice4 not in list:
        print('\n')
        print(red('Wrong. Please, try again'))
        print('\n')
        time.sleep(0.5)
        print('💻 1. Laptop')
        print('📺 2. Screen')
        print('\n')
        choice4 = str(input('Write the number of your choice: '))
        time.sleep(0.5)

      else:
        i = True
        print('\n')
        print_slowly('# LOADING #')

    time.sleep(1.5)
    print('\n')
    clear_output(wait=True)

  #2ND - BRAND NEW OR SECOND HAND

    print('Are you interested in '+(black('Brand New','bold'))+' or '+(black('Second-hand','bold'))+' items?')
    print('\n')
    time.sleep(0.5)
    print('👶 1. Brand New')
    print('👴 2. Second-hand')
    print('\n')
    choice5 = str(input('Write the number of your choice: '))
    time.sleep(0.5)

    i = False
    
    while i == False:

      if choice5 not in list:
        print('\n')
        print(red('Wrong. Please, try again'))
        print('\n')
        time.sleep(0.5)
        print('👶 1. Brand New')
        print('👴 2. Second-hand')
        print('\n')
        choice5 = str(input('Write the number of your choice: '))
        time.sleep(0.5)

      else:
        i = True
        print('\n')
        print_slowly('# LOADING #')

    time.sleep(1.5)
    print('\n')
    clear_output(wait=True)

    # BRAND NEW LAPTOPS
    if choice4 == '1' and choice5 =='1':

      print('These are the '+(black('BEST New Brand Laptops','bold'))+' segmented by '+(black('RAM','bold'))+' and ordered by quality/price ratio')
      print('\n')
      print((black('Group 1: 2, 4, 6 & 8 GB','bold')))
      print('\n')
      laptops_G1=laptops[(laptops['Product status'] == 'Brand New') & (laptops['RAM Type'] == 'RAM1')].sort_values(by = 'Ratio RAM/€', ascending=False).head(5)
      print(laptops_G1[['Name','Price','Brand']])
      print('\n')

      print((black('Group 2: 12, 16 & 20 GB','bold')))
      print('\n')
      laptops_G2=laptops[(laptops['Product status'] == 'Brand New') & (laptops['RAM Type'] == 'RAM2')].sort_values(by = 'Ratio RAM/€', ascending=False).head(5)
      print(laptops_G2[['Name','Price','Brand']])
      print('\n')

      print((black('Group 3: 24, 32, 40 & 64 GB','bold')))
      print('\n')
      laptops_G3=laptops[(laptops['Product status'] == 'Brand New') & (laptops['RAM Type'] == 'RAM3')].sort_values(by = 'Ratio RAM/€', ascending=False).head(5)
      print(laptops_G3[['Name','Price','Brand']])
      print('\n')
      print((black('Note: quality standard was calculated by GB/Price ratio','italic')))
      print('\n')

    # SECOND HAND LAPTOPS
    if choice4 == '1' and choice5 =='2':

      print('These are the '+(black('BEST Second Hand Laptops','bold'))+' segmented by '+(black('RAM','bold'))+' and ordered by quality/price ratio')
      print('\n')
      print((black('Group 1: 2, 4, 6 & 8 GB','bold')))
      print('\n')
      laptops_G1_sh=laptops[(laptops['Product status'] == 'Refurbished') & (laptops['RAM Type'] == 'RAM1')].sort_values(by = 'Ratio RAM/€', ascending=False).head(5)
      print(laptops_G1_sh[['Name','Price','Brand']])
      print('\n')

      print((black('Group 2: 12, 16 & 20 GB','bold')))
      print('\n')
      laptops_G2_sh=laptops[(laptops['Product status'] == 'Refurbished') & (laptops['RAM Type'] == 'RAM2')].sort_values(by = 'Ratio RAM/€', ascending=False).head(5)
      print(laptops_G2_sh[['Name','Price','Brand']])
      print('\n')

      print((black('Group 3: 24, 32, 40 & 64 GB','bold')))
      print('\n')
      laptops_G3_sh=laptops[(laptops['Product status'] == 'Refurbished') & (laptops['RAM Type'] == 'RAM3')].sort_values(by = 'Ratio RAM/€', ascending=False).head(5)
      print(laptops_G3_sh[['Name','Price','Brand']])
      print('\n')
      print((black('Note: quality standard was calculated by GB/Price ratio','italic')))
      print('\n')



    # BRAND NEW SCREENS
    if choice4 == '2' and choice5 =='1':
     
      print('These are the '+(black('BEST New Brand Screens','bold'))+' segmented by '+(black('Inch Type','bold'))+' and ordered by quality/price ratio')
      print('\n')
      print((black('Type Inches Segmentation','bold')))
      print('\n')

      print((black('Type Inch1: ','bold'))+'below 27"')
      print('\n')
      screen_G1=screens[(screens['Product status'] == 'Brand New') & (screens['Inches Type'] == 'Inch1')].sort_values(by = 'Ratio Inches/€', ascending=False).head(5)
      print(screen_G1[['Name','Price','Brand']])
      print('\n')

      print((black('Type Inch2: ','bold'))+'above 27 and below 40"')
      print('\n')
      screen_G2=screens[(screens['Product status'] == 'Brand New') & (screens['Inches Type'] == 'Inch2')].sort_values(by = 'Ratio Inches/€', ascending=False).head(5)
      print(screen_G2[['Name','Price','Brand']])
      print('\n')

      print((black('Type Inch3: ','bold'))+'above 40"')
      print('\n')
      screen_G3=screens[(screens['Product status'] == 'Brand New') & (screens['Inches Type'] == 'Inch3')].sort_values(by = 'Ratio Inches/€', ascending=False).head(5)
      print(screen_G3[['Name','Price','Brand']])
      print('\n')
      print((black('Note: quality standard was calculated by Inch size/Price ratio','italic')))
      print('\n')

    # SECOND HAND SCREENS BRANDS
    if choice4 == '2' and choice5 =='2':
     
      print('These are the '+(black('BEST Second Hand Screens','bold'))+' segmented by '+(black('Inch Type','bold'))+' and ordered by quality/price ratio')
      print('\n')
      print((black('Type Inches Segmentation','bold')))
      print('\n')

      print((black('Type Inch1: ','bold'))+'below 27"')
      print('\n')
      screen_G1_sc=screens[(screens['Product status'] == 'Refurbished') & (screens['Inches Type'] == 'Inch1')].sort_values(by = 'Ratio Inches/€', ascending=False).head(5)
      print(screen_G1_sc[['Name','Price','Brand']])
      print('\n')

      print((black('Type Inch2: ','bold'))+'above 27 and below 40"')
      print('\n')
      screen_G2_sc=screens[(screens['Product status'] == 'Refurbished') & (screens['Inches Type'] == 'Inch2')].sort_values(by = 'Ratio Inches/€', ascending=False).head(5)
      print(screen_G2_sc[['Name','Price','Brand']])
      print('\n')

      print((black('Type Inch3: ','bold'))+'above 40"')
      print('\n')
      screen_G3_sc=screens[(screens['Product status'] == 'Refurbished') & (screens['Inches Type'] == 'Inch3')].sort_values(by = 'Ratio Inches/€', ascending=False).head(5)
      print(screen_G3_sc[['Name','Price','Brand']])
      print('\n')
      print((black('Note: quality standard was calculated by Inch size/Price ratio','italic')))
      print('\n')







    print('Do you want to keep going? Y/N')
    print('\n')
    continue1 = str(input('Write your choice: '))
    print('\n')

    #CONTINUE?


    if continue1.lower() == 'y':
      m = True
      clear_output(wait=True)
    elif continue1.lower() == 'n':
      m = False
      break
    else:
      m = False
      break

'''
# SENDING EMAIL

clear_output(wait=True)

sender_email = str(input('From which email you want to share these recommendations?: '))
receiver_email = e
subject = 'Hello '+a+'! Here the info you are interested'

print('For sending the email share me your email password and press enter:')
sender_password = getpass.getpass()


contents = ['Hope this info is useful!']

filename = [] #DO AN APPEND OF THE CSV files

# initiating connection with SMTP server
yag = yagmail.SMTP(user=sender_email,
                   password=sender_password)

# Adding Content and sending it
yag.send(to = receiver_email, 
         subject = subject,
         contents = contents,
         attachments = filename)

'''
# Out:
# These are the BEST New Brand Screens segmented by Inch Type and ordered by quality/price ratio
#
#
# Type Inches Segmentation
#
#
# Type Inch1: below 27"
#
#
#                                                  Name   Price      Brand
# 18  Monitor - Nilox - MONITOR 21,5” 5MS, VGA y HDM...  100.71      NILOX
# 13  Monitor - 193V5LSB2/10 PHILIPS, 19", HD-ready,...   92.34    PHILIPS
# 62  Monitor - NXM24FHD01 NILOX, 24", Full-HD, 5 ms...  116.84      NILOX
# 30  Monitor - SC26-M1F SCHNEIDER, 25,7", Full-HD, ...  129.00  SCHNEIDER
# 55  Monitor - PRO MP241X MSI, 24", Full-HD, 4 ms, ...  120.98        MSI
#
#
# Type Inch2: above 27 and below 40"
#
#
#                                                   Name   Price      Brand
# 15   Monitor - LG 32MN500M-B, 31,5" Full-HD, 5 ms, ...  168.00         LG
# 324  Monitor - NXM32FHD01 NILOX, 32", Full-HD, 5 ms...  187.24      NILOX
# 341  Monitor - HL 320 UPB HANNSPREE, 32", Full-HD, ...  195.52  HANNSPREE
# 83   Monitor gaming - 32GN500B-AEU LG, 32", Full-HD...  213.88         LG
# 61   Monitor gaming - 8806091246417 LG, 29", HD, 5 ...  201.02         LG
#
#
# Type Inch3: above 40"
#
#
#                                                  Name   Price    Brand
# 36  Monitor - Xiaomi OB02608 Mi Desktop Monitor 27...  142.00   XIAOMI
# 89  Monitor - NXM27FHD01 NILOX, 27", Full-HD, 5 ms...  147.48    NILOX
# 11  Monitor gaming - 62AAKAT6EU LENOVO, 27", Full-...  148.41   LENOVO
# 66  Monitor - Philips 271V8L/00, 27" FHD, VA, 4 ms...  152.00  PHILIPS
# 86  Monitor gaming L27e-30(C20270FL0) - LENOVO, 27...  152.80   LENOVO
#
#
# Note: quality standard was calculated by Inch size/Price ratio
#
#
# Do you want to keep going? Y/N
#
#
# Write your choice: n
# "\n# SENDING EMAIL\n\nclear_output(wait=True)\n\nsender_email = str(input('From which email you want to share these recommendations?: '))\nreceiver_email = e\nsubject = 'Hello '+a+'! Here the info you are interested'\n\nprint('For sending the email share me your email password and press enter:')\nsender_password = getpass.getpass()\n\n\ncontents = ['Hope this info is useful!']\n\nfilename = [] #DO AN APPEND OF THE CSV files\n\n# initiating connection with SMTP server\nyag = yagmail.SMTP(user=sender_email,\n                   password=sender_password)\n\n# Adding Content and sending it\nyag.send(to = receiver_email, \n         subject = subject,\n         contents = contents,\n         attachments = filename)\n\n"
